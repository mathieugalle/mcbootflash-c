# %%
def bytes_to_hex_string(byte_data, addSpaces = True):
    hex_bytes = [f"{byte:02x}" for byte in bytes(byte_data)]
    if addSpaces:
        return ' '.join(hex_bytes, )
    else:
        return ''.join(hex_bytes, )

# now testing the segments addSegment function, adding to segments vector
import importlib
import _util
importlib.reload(_util)

from _types import BootAttrs
bootattrs = BootAttrs(
        version=258,
        max_packet_length=256,
        device_id=13398,
        erase_size=2048,
        write_size=8,
        memory_range=(6144, 174080),
        has_checksum=True,
    )

total_bytes, chunks, debug_parsed_records, debug_segments_before_crop, segments = _util.chunked("../mcbootflash/tests/testcases/flash/VR_Inertiel_PIC24FJ64GP202_V100.X.production.hex", bootattrs)

chunks_arr = []
for s in chunks:
    chunks_arr.append(s)

print("number of chunks : !!")
print(len(chunks_arr))
for s in chunks_arr:
    t = [s.minimum_address, s.maximum_address, s.data, s.word_size_bytes]
    print(f"Segment({t[0]}, {t[1]}, hexStringToBytes(\"{bytes_to_hex_string(t[2], addSpaces=False)}\"), {t[3]}),")
# Out:
# number of debug_parsed_records 2140
# first debug_parsed_records  (0, 8, bytearray(b'\xf0"\x04\x00\x00\x00\x00\x00'), 1)
# second debug_parsed_records  (8, 24, bytearray(b'\x04"\x00\x00\x08"\x00\x00\x0c"\x00\x00\x10"\x00\x00'), 1)
# n-th debug_parsed_records  (17640, 17648, bytearray(b'\x00"\x04\x00\x00\x00\x00\x00'), 1)
# debug_segments_before_crop len :  16
# here data
# 8168
# ...
# size :  240
# offset :  720
# address + offset  17104
# address + offset + size 17344
# data[offset:offset + size] len  240
# offset :  960
# address + offset  17344
# address + offset + size 17584
# data[offset:offset + size] len  240
# here data
# 24776
# ...
# size :  240
# offset :  720
# address + offset  25296
# address + offset + size 25536
# data[offset:offset + size] len  240
# offset :  960
# address + offset  25536
# address + offset + size 25776
# data[offset:offset + size] len  240
# here data
# 8
# ffffff0000000000
# size :  240
# here data
# 8
# ffffff0000000000
# size :  240
# here data
# 8
# 00ffff0000000000
# size :  240
# here data
# 8
# 63ffff0000000000
# size :  240
# here data
# 8
# 9fffff0000000000
# size :  240
# here data
# 8
# ffffff0000000000
# size :  240
# here data
# 8
# dfffff0000000000
# size :  240
# here data
# 8
# 0000ff0000000000
# size :  240
# here data
# 8
# 0000ff0000000000
# size :  240
# here data
# 8
# 0000ff0000000000
# size :  240
# here data
# 8
# 0000ff0000000000
# size :  240
# here data
# 8
# ffffff0000000000
# size :  240
# here data
# 8
# efffff0000000000
# size :  240
# number of chunks : !!
# 152
# Segment(16384, 16624, hexStringToBytes("..."), 2),
# Segment(16624, 16864, hexStringToBytes("..."), 2),
# Segment(16864, 17104, hexStringToBytes("..."), 2),
# Segment(17104, 17344, hexStringToBytes("..."), 2),
# Segment(17344, 17584, hexStringToBytes("..."), 2),
# Segment(17584, 17824, hexStringToBytes("..."), 2),
# Segment(17824, 18064, hexStringToBytes("..."), 2),
# Segment(18064, 18304, hexStringToBytes("..."), 2),
# Segment(18304, 18544, hexStringToBytes("..."), 2),
# Segment(18544, 18784, hexStringToBytes("..."), 2),
# Segment(18784, 19024, hexStringToBytes("..."), 2),
# Segment(19024, 19264, hexStringToBytes("..."), 2),
# Segment(19264, 19504, hexStringToBytes("..."), 2),
# Segment(19504, 19744, hexStringToBytes("..."), 2),
# Segment(19744, 19984, hexStringToBytes("..."), 2),
# Segment(19984, 20224, hexStringToBytes("..."), 2),
# Segment(20224, 20464, hexStringToBytes("..."), 2),
# Segment(20464, 20704, hexStringToBytes("..."), 2),
# Segment(20704, 20944, hexStringToBytes("..."), 2),
# Segment(20944, 21184, hexStringToBytes("..."), 2),
# Segment(21184, 21424, hexStringToBytes("..."), 2),
# Segment(21424, 21664, hexStringToBytes("..."), 2),
# Segment(21664, 21904, hexStringToBytes("..."), 2),
# Segment(21904, 22144, hexStringToBytes("..."), 2),
# Segment(22144, 22384, hexStringToBytes("..."), 2),
# Segment(22384, 22624, hexStringToBytes("..."), 2),
# Segment(22624, 22864, hexStringToBytes("..."), 2),
# Segment(22864, 23104, hexStringToBytes("..."), 2),
# Segment(23104, 23344, hexStringToBytes("..."), 2),
# Segment(23344, 23584, hexStringToBytes("..."), 2),
# Segment(23584, 23824, hexStringToBytes("..."), 2),
# Segment(23824, 24064, hexStringToBytes("..."), 2),
# Segment(24064, 24304, hexStringToBytes("..."), 2),
# Segment(24304, 24544, hexStringToBytes("..."), 2),
# Segment(24544, 24784, hexStringToBytes("ffff370000000000"), 2),
# Segment(24576, 24816, hexStringToBytes("..."), 2),
# Segment(24816, 25056, hexStringToBytes("..."), 2),
# Segment(25056, 25296, hexStringToBytes("..."), 2),
# Segment(25296, 25536, hexStringToBytes("..."), 2),
# Segment(25536, 25776, hexStringToBytes("..."), 2),
# Segment(25776, 26016, hexStringToBytes("..."), 2),
# Segment(26016, 26256, hexStringToBytes("..."), 2),
# Segment(26256, 26496, hexStringToBytes("..."), 2),
# Segment(26496, 26736, hexStringToBytes("..."), 2),
# Segment(26736, 26976, hexStringToBytes("..."), 2),
# Segment(26976, 27216, hexStringToBytes("..."), 2),
# Segment(27216, 27456, hexStringToBytes("..."), 2),
# Segment(27456, 27696, hexStringToBytes("..."), 2),
# Segment(27696, 27936, hexStringToBytes("..."), 2),
# Segment(27936, 28176, hexStringToBytes("..."), 2),
# Segment(28176, 28416, hexStringToBytes("..."), 2),
# Segment(28416, 28656, hexStringToBytes("..."), 2),
# Segment(28656, 28896, hexStringToBytes("..."), 2),
# Segment(28896, 29136, hexStringToBytes("..."), 2),
# Segment(29136, 29376, hexStringToBytes("..."), 2),
# Segment(29376, 29616, hexStringToBytes("..."), 2),
# Segment(29616, 29856, hexStringToBytes("..."), 2),
# Segment(29856, 30096, hexStringToBytes("..."), 2),
# Segment(30096, 30336, hexStringToBytes("..."), 2),
# Segment(30336, 30576, hexStringToBytes("..."), 2),
# Segment(30576, 30816, hexStringToBytes("..."), 2),
# Segment(30816, 31056, hexStringToBytes("..."), 2),
# Segment(31056, 31296, hexStringToBytes("..."), 2),
# Segment(31296, 31536, hexStringToBytes("..."), 2),
# Segment(31536, 31776, hexStringToBytes("..."), 2),
# Segment(31776, 32016, hexStringToBytes("..."), 2),
# Segment(32016, 32256, hexStringToBytes("..."), 2),
# Segment(32256, 32496, hexStringToBytes("..."), 2),
# Segment(32496, 32736, hexStringToBytes("..."), 2),
# Segment(32736, 32976, hexStringToBytes("..."), 2),
# Segment(32976, 33216, hexStringToBytes("..."), 2),
# Segment(33216, 33456, hexStringToBytes("..."), 2),
# Segment(33456, 33696, hexStringToBytes("..."), 2),
# Segment(33696, 33936, hexStringToBytes("..."), 2),
# Segment(33936, 34176, hexStringToBytes("..."), 2),
# Segment(34176, 34416, hexStringToBytes("..."), 2),
# Segment(34416, 34656, hexStringToBytes("..."), 2),
# Segment(34656, 34896, hexStringToBytes("..."), 2),
# Segment(34896, 35136, hexStringToBytes("..."), 2),
# Segment(35136, 35376, hexStringToBytes("..."), 2),
# Segment(35376, 35616, hexStringToBytes("..."), 2),
# Segment(35616, 35856, hexStringToBytes("..."), 2),
# Segment(35856, 36096, hexStringToBytes("..."), 2),
# Segment(36096, 36336, hexStringToBytes("..."), 2),
# Segment(36336, 36576, hexStringToBytes("..."), 2),
# Segment(36576, 36816, hexStringToBytes("..."), 2),
# Segment(36816, 37056, hexStringToBytes("..."), 2),
# Segment(37056, 37296, hexStringToBytes("..."), 2),
# Segment(37296, 37536, hexStringToBytes("..."), 2),
# Segment(37536, 37776, hexStringToBytes("..."), 2),
# Segment(37776, 38016, hexStringToBytes("..."), 2),
# Segment(38016, 38256, hexStringToBytes("..."), 2),
# Segment(38256, 38496, hexStringToBytes("..."), 2),
# Segment(38496, 38736, hexStringToBytes("..."), 2),
# Segment(38736, 38976, hexStringToBytes("..."), 2),
# Segment(38976, 39216, hexStringToBytes("..."), 2),
# Segment(39216, 39456, hexStringToBytes("..."), 2),
# Segment(39456, 39696, hexStringToBytes("..."), 2),
# Segment(39696, 39936, hexStringToBytes("..."), 2),
# Segment(39936, 40176, hexStringToBytes("..."), 2),
# Segment(40176, 40416, hexStringToBytes("..."), 2),
# Segment(40416, 40656, hexStringToBytes("..."), 2),
# Segment(40656, 40896, hexStringToBytes("..."), 2),
# Segment(40896, 41136, hexStringToBytes("..."), 2),
# Segment(41136, 41376, hexStringToBytes("..."), 2),
# Segment(41376, 41616, hexStringToBytes("..."), 2),
# Segment(41616, 41856, hexStringToBytes("..."), 2),
# Segment(41856, 42096, hexStringToBytes("..."), 2),
# Segment(42096, 42336, hexStringToBytes("..."), 2),
# Segment(42336, 42576, hexStringToBytes("..."), 2),
# Segment(42576, 42816, hexStringToBytes("..."), 2),
# Segment(42816, 43056, hexStringToBytes("..."), 2),
# Segment(43056, 43296, hexStringToBytes("..."), 2),
# Segment(43296, 43536, hexStringToBytes("..."), 2),
# Segment(43536, 43776, hexStringToBytes("..."), 2),
# Segment(43776, 44016, hexStringToBytes("..."), 2),
# Segment(44016, 44256, hexStringToBytes("..."), 2),
# Segment(44256, 44496, hexStringToBytes("..."), 2),
# Segment(44496, 44736, hexStringToBytes("..."), 2),
# Segment(44736, 44976, hexStringToBytes("..."), 2),
# Segment(44976, 45216, hexStringToBytes("..."), 2),
# Segment(45216, 45456, hexStringToBytes("..."), 2),
# Segment(45456, 45696, hexStringToBytes("..."), 2),
# Segment(45696, 45936, hexStringToBytes("..."), 2),
# Segment(45936, 46176, hexStringToBytes("..."), 2),
# Segment(46176, 46416, hexStringToBytes("..."), 2),
# Segment(46416, 46656, hexStringToBytes("..."), 2),
# Segment(46656, 46896, hexStringToBytes("..."), 2),
# Segment(46896, 47136, hexStringToBytes("..."), 2),
# Segment(47136, 47376, hexStringToBytes("..."), 2),
# Segment(47376, 47616, hexStringToBytes("..."), 2),
# Segment(47616, 47856, hexStringToBytes("..."), 2),
# Segment(47856, 48096, hexStringToBytes("..."), 2),
# Segment(48096, 48336, hexStringToBytes("..."), 2),
# Segment(48336, 48576, hexStringToBytes("..."), 2),
# Segment(48576, 48816, hexStringToBytes("..."), 2),
# Segment(48816, 49056, hexStringToBytes("..."), 2),
# Segment(49056, 49296, hexStringToBytes("..."), 2),
# Segment(49296, 49536, hexStringToBytes("8007780040aa2000000188000080fa00000006000000fa002bff0700cce00700b9ff0700dafe070089fe07002cfe07000080fa0000000600"), 2),
# Segment(89600, 89840, hexStringToBytes("ffffff0000000000"), 2),
# Segment(89632, 89872, hexStringToBytes("ffffff0000000000"), 2),
# Segment(89648, 89888, hexStringToBytes("00ffff0000000000"), 2),
# Segment(89656, 89896, hexStringToBytes("63ffff0000000000"), 2),
# Segment(89664, 89904, hexStringToBytes("9fffff0000000000"), 2),
# Segment(89672, 89912, hexStringToBytes("ffffff0000000000"), 2),
# Segment(89680, 89920, hexStringToBytes("dfffff0000000000"), 2),
# Segment(89688, 89928, hexStringToBytes("0000ff0000000000"), 2),
# Segment(89696, 89936, hexStringToBytes("0000ff0000000000"), 2),
# Segment(89704, 89944, hexStringToBytes("0000ff0000000000"), 2),
# Segment(89712, 89952, hexStringToBytes("0000ff0000000000"), 2),
# Segment(89720, 89960, hexStringToBytes("ffffff0000000000"), 2),
# Segment(89728, 89968, hexStringToBytes("efffff0000000000"), 2),
