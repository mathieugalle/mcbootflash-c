# %%
def bytes_to_hex_string(byte_data, addSpaces = True):
    hex_bytes = [f"{byte:02x}" for byte in bytes(byte_data)]
    if addSpaces:
        return ' '.join(hex_bytes, )
    else:
        return ''.join(hex_bytes, )

# now testing the segments addSegment function, adding to segments vector
import importlib
import _util
importlib.reload(_util)

from _types import BootAttrs
bootattrs = BootAttrs(
        version=258,
        max_packet_length=256,
        device_id=13398,
        erase_size=2048,
        write_size=8,
        memory_range=(8192, 43006), # 8192, end 43006 # using true memory_range from a bootloader
        has_checksum=False,
    )

total_bytes, chunks, debug_parsed_records, debug_segments_before_crop, segments = \
_util.chunked("../mcbootflash/tests/testcases/flash/xdbVR_UMTS_pic24fj64gp202.X.production.hex", bootattrs)

chunks_arr = []
for s in chunks:
    chunks_arr.append(s)

print("number of chunks : ")
print(len(chunks_arr))
for s in chunks_arr:
    t = [s.minimum_address, s.maximum_address, s.data, s.word_size_bytes]
    print(f"Segment({t[0]}, {t[1]}, hexStringToBytes(\"{bytes_to_hex_string(t[2], addSpaces=False)}\"), {t[3]}),")
# Out:
# number of debug_parsed_records 1808
# first debug_parsed_records  (0, 8, bytearray(b'\xf0"\x04\x00\x00\x00\x00\x00'), 1)
# second debug_parsed_records  (8, 24, bytearray(b'\x04"\x00\x00\x08"\x00\x00\x0c"\x00\x00\x10"\x00\x00'), 1)
# n-th debug_parsed_records  (17640, 17648, bytearray(b'\x00"\x04\x00\x00\x00\x00\x00'), 1)
# debug_segments_before_crop len :  15
# here data
# 27672
# ...
# size :  240
# offset :  720
# address + offset  17104
# address + offset + size 17344
# data[offset:offset + size] len  240
# offset :  960
# address + offset  17344
# address + offset + size 17584
# data[offset:offset + size] len  240
# number of chunks :
# 116
# Segment(16384, 16624, hexStringToBytes("..."), 2),
# Segment(16624, 16864, hexStringToBytes("..."), 2),
# Segment(16864, 17104, hexStringToBytes("..."), 2),
# Segment(17104, 17344, hexStringToBytes("..."), 2),
# Segment(17344, 17584, hexStringToBytes("..."), 2),
# Segment(17584, 17824, hexStringToBytes("..."), 2),
# Segment(17824, 18064, hexStringToBytes("..."), 2),
# Segment(18064, 18304, hexStringToBytes("..."), 2),
# Segment(18304, 18544, hexStringToBytes("..."), 2),
# Segment(18544, 18784, hexStringToBytes("..."), 2),
# Segment(18784, 19024, hexStringToBytes("..."), 2),
# Segment(19024, 19264, hexStringToBytes("..."), 2),
# Segment(19264, 19504, hexStringToBytes("..."), 2),
# Segment(19504, 19744, hexStringToBytes("..."), 2),
# Segment(19744, 19984, hexStringToBytes("..."), 2),
# Segment(19984, 20224, hexStringToBytes("..."), 2),
# Segment(20224, 20464, hexStringToBytes("..."), 2),
# Segment(20464, 20704, hexStringToBytes("..."), 2),
# Segment(20704, 20944, hexStringToBytes("..."), 2),
# Segment(20944, 21184, hexStringToBytes("..."), 2),
# Segment(21184, 21424, hexStringToBytes("..."), 2),
# Segment(21424, 21664, hexStringToBytes("..."), 2),
# Segment(21664, 21904, hexStringToBytes("..."), 2),
# Segment(21904, 22144, hexStringToBytes("..."), 2),
# Segment(22144, 22384, hexStringToBytes("..."), 2),
# Segment(22384, 22624, hexStringToBytes("..."), 2),
# Segment(22624, 22864, hexStringToBytes("..."), 2),
# Segment(22864, 23104, hexStringToBytes("..."), 2),
# Segment(23104, 23344, hexStringToBytes("..."), 2),
# Segment(23344, 23584, hexStringToBytes("..."), 2),
# Segment(23584, 23824, hexStringToBytes("..."), 2),
# Segment(23824, 24064, hexStringToBytes("..."), 2),
# Segment(24064, 24304, hexStringToBytes("..."), 2),
# Segment(24304, 24544, hexStringToBytes("..."), 2),
# Segment(24544, 24784, hexStringToBytes("..."), 2),
# Segment(24784, 25024, hexStringToBytes("..."), 2),
# Segment(25024, 25264, hexStringToBytes("..."), 2),
# Segment(25264, 25504, hexStringToBytes("..."), 2),
# Segment(25504, 25744, hexStringToBytes("..."), 2),
# Segment(25744, 25984, hexStringToBytes("..."), 2),
# Segment(25984, 26224, hexStringToBytes("..."), 2),
# Segment(26224, 26464, hexStringToBytes("..."), 2),
# Segment(26464, 26704, hexStringToBytes("..."), 2),
# Segment(26704, 26944, hexStringToBytes("..."), 2),
# Segment(26944, 27184, hexStringToBytes("..."), 2),
# Segment(27184, 27424, hexStringToBytes("..."), 2),
# Segment(27424, 27664, hexStringToBytes("..."), 2),
# Segment(27664, 27904, hexStringToBytes("..."), 2),
# Segment(27904, 28144, hexStringToBytes("..."), 2),
# Segment(28144, 28384, hexStringToBytes("..."), 2),
# Segment(28384, 28624, hexStringToBytes("..."), 2),
# Segment(28624, 28864, hexStringToBytes("..."), 2),
# Segment(28864, 29104, hexStringToBytes("..."), 2),
# Segment(29104, 29344, hexStringToBytes("..."), 2),
# Segment(29344, 29584, hexStringToBytes("..."), 2),
# Segment(29584, 29824, hexStringToBytes("..."), 2),
# Segment(29824, 30064, hexStringToBytes("..."), 2),
# Segment(30064, 30304, hexStringToBytes("..."), 2),
# Segment(30304, 30544, hexStringToBytes("..."), 2),
# Segment(30544, 30784, hexStringToBytes("..."), 2),
# Segment(30784, 31024, hexStringToBytes("..."), 2),
# Segment(31024, 31264, hexStringToBytes("..."), 2),
# Segment(31264, 31504, hexStringToBytes("..."), 2),
# Segment(31504, 31744, hexStringToBytes("..."), 2),
# Segment(31744, 31984, hexStringToBytes("..."), 2),
# Segment(31984, 32224, hexStringToBytes("..."), 2),
# Segment(32224, 32464, hexStringToBytes("..."), 2),
# Segment(32464, 32704, hexStringToBytes("..."), 2),
# Segment(32704, 32944, hexStringToBytes("..."), 2),
# Segment(32944, 33184, hexStringToBytes("..."), 2),
# Segment(33184, 33424, hexStringToBytes("..."), 2),
# Segment(33424, 33664, hexStringToBytes("..."), 2),
# Segment(33664, 33904, hexStringToBytes("..."), 2),
# Segment(33904, 34144, hexStringToBytes("..."), 2),
# Segment(34144, 34384, hexStringToBytes("..."), 2),
# Segment(34384, 34624, hexStringToBytes("..."), 2),
# Segment(34624, 34864, hexStringToBytes("..."), 2),
# Segment(34864, 35104, hexStringToBytes("..."), 2),
# Segment(35104, 35344, hexStringToBytes("..."), 2),
# Segment(35344, 35584, hexStringToBytes("..."), 2),
# Segment(35584, 35824, hexStringToBytes("..."), 2),
# Segment(35824, 36064, hexStringToBytes("..."), 2),
# Segment(36064, 36304, hexStringToBytes("..."), 2),
# Segment(36304, 36544, hexStringToBytes("..."), 2),
# Segment(36544, 36784, hexStringToBytes("..."), 2),
# Segment(36784, 37024, hexStringToBytes("..."), 2),
# Segment(37024, 37264, hexStringToBytes("..."), 2),
# Segment(37264, 37504, hexStringToBytes("..."), 2),
# Segment(37504, 37744, hexStringToBytes("..."), 2),
# Segment(37744, 37984, hexStringToBytes("..."), 2),
# Segment(37984, 38224, hexStringToBytes("..."), 2),
# Segment(38224, 38464, hexStringToBytes("..."), 2),
# Segment(38464, 38704, hexStringToBytes("..."), 2),
# Segment(38704, 38944, hexStringToBytes("..."), 2),
# Segment(38944, 39184, hexStringToBytes("..."), 2),
# Segment(39184, 39424, hexStringToBytes("..."), 2),
# Segment(39424, 39664, hexStringToBytes("..."), 2),
# Segment(39664, 39904, hexStringToBytes("..."), 2),
# Segment(39904, 40144, hexStringToBytes("..."), 2),
# Segment(40144, 40384, hexStringToBytes("..."), 2),
# Segment(40384, 40624, hexStringToBytes("..."), 2),
# Segment(40624, 40864, hexStringToBytes("..."), 2),
# Segment(40864, 41104, hexStringToBytes("..."), 2),
# Segment(41104, 41344, hexStringToBytes("..."), 2),
# Segment(41344, 41584, hexStringToBytes("..."), 2),
# Segment(41584, 41824, hexStringToBytes("..."), 2),
# Segment(41824, 42064, hexStringToBytes("..."), 2),
# Segment(42064, 42304, hexStringToBytes("..."), 2),
# Segment(42304, 42544, hexStringToBytes("..."), 2),
# Segment(42544, 42784, hexStringToBytes("..."), 2),
# Segment(42784, 43024, hexStringToBytes("..."), 2),
# Segment(43024, 43264, hexStringToBytes("..."), 2),
# Segment(43264, 43504, hexStringToBytes("..."), 2),
# Segment(43504, 43744, hexStringToBytes("..."), 2),
# Segment(43744, 43984, hexStringToBytes("..."), 2),
# Segment(43984, 44224, hexStringToBytes("0000fa00c09d200080077800409f2000000188000080fa00000006000000fa0074ff0700daff0700b0ff0700a4e507006afb070021ff0700c4fe07000080fa0000000600ffff3700"), 2),
