# %%
def bytes_to_hex_string(byte_data, addSpaces = True):
    hex_bytes = [f"{byte:02x}" for byte in bytes(byte_data)]
    if addSpaces:
        return ' '.join(hex_bytes, )
    else:
        return ''.join(hex_bytes, )

# now testing the segments addSegment function, adding to segments vector
import importlib
import _util
importlib.reload(_util)

from _types import BootAttrs
bootattrs = BootAttrs(
        version=258,
        max_packet_length=256,
        device_id=13398,
        erase_size=2048,
        write_size=8,
        memory_range=(6144, 174080),
        has_checksum=True,
    )
total_bytes, chunks, debug_parsed_records, debug_segments_before_crop, segments = _util.chunked("../mcbootflash/tests/testcases/flash/VitiAppDelivery.X.production.hex", bootattrs)

chunks_arr = []
for s in chunks:
    chunks_arr.append(s)

print(len(chunks_arr))
for s in chunks_arr:
    t = [s.minimum_address, s.maximum_address, s.data, s.word_size_bytes]
    print(f"Segment({t[0]}, {t[1]}, hexStringToBytes(\"{bytes_to_hex_string(t[2], addSpaces=False)}\"), {t[3]}),")
# Out:
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# ...

# %%
def bytes_to_hex_string(byte_data, addSpaces = True):
    hex_bytes = [f"{byte:02x}" for byte in bytes(byte_data)]
    if addSpaces:
        return ' '.join(hex_bytes, )
    else:
        return ''.join(hex_bytes, )

# now testing the segments addSegment function, adding to segments vector
import importlib
import _util
importlib.reload(_util)

from _types import BootAttrs
bootattrs = BootAttrs(
        version=258,
        max_packet_length=256,
        device_id=13398,
        erase_size=2048,
        write_size=8,
        memory_range=(6144, 174080),
        has_checksum=True,
    )
total_bytes, chunks, debug_parsed_records, debug_segments_before_crop, segments = _util.chunked("../mcbootflash/tests/testcases/flash/VitiAppDelivery.X.production.hex", bootattrs)

for s in segments:
    t = [s.minimum_address, s.maximum_address, s.data, s.word_size_bytes]
    print(f"Segment({t[0]}, {t[1]}, hexStringToBytes(\"{bytes_to_hex_string(t[2], addSpaces=False)}\"), {t[3]}),")
# Out:
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# new extended linear :  0
# new extended linear :  65536
# ...
